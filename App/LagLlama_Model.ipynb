# %%
import warnings

warnings.filterwarnings(action='ignore', category=FutureWarning) # setting ignore as a parameter and further adding category
warnings.simplefilter('ignore')
warnings.filterwarnings("ignore")

import logging
logging.getLogger().setLevel(logging.WARNING)

from itertools import islice

import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import torch

from gluonts.torch.distributions.studentT import StudentTOutput
torch.serialization.add_safe_globals([StudentTOutput])

from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.evaluation import Evaluator, make_evaluation_predictions

from gluonts.torch.modules.loss import NegativeLogLikelihood
# Add the class to safe globals
torch.serialization.add_safe_globals([NegativeLogLikelihood])
from lag_llama.gluon.estimator import LagLlamaEstimator

from matplotlib import pyplot as plt

# %%
def _get_lag_llama_predictions(dataset, prediction_length, num_samples=100):
    # Load the checkpoint with map_location set to 'cpu'
    ckpt = torch.load("lag-llama.ckpt", map_location=torch.device('cuda'),weights_only=True,)
    estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

    # Initialize the estimator with the required arguments
    estimator = LagLlamaEstimator(
        ckpt_path="lag-llama.ckpt",
        prediction_length=prediction_length,
        context_length=32,

        # scaling="mean",
        nonnegative_pred_samples=True,
        aug_prob=0,
        lr=0.0005,
        
        # estimator args
        input_size=estimator_args["input_size"],
        n_layer=estimator_args["n_layer"],
        n_embd_per_head=estimator_args["n_embd_per_head"],
        n_head=estimator_args["n_head"],
        scaling=estimator_args["scaling"],
        time_feat=estimator_args["time_feat"],

         # linear positional encoding scaling
        rope_scaling={
            "type": "linear",
            "factor": max(1.0, (32 + prediction_length) / estimator_args["context_length"]),
        },
        
        batch_size=32,
        num_parallel_samples=num_samples,
        trainer_kwargs = {"max_epochs": 200,}, # <- lightning trainer arguments
    )


    # Create the lightning module, transformation, and predictor
    lightning_module = estimator.create_lightning_module()
    transformation = estimator.create_transformation()
    predictor = estimator.create_predictor(transformation, lightning_module)


    # Generate forecasts and time series predictions
    forecast_it, ts_it = make_evaluation_predictions(
        dataset=dataset, predictor=predictor, num_samples=num_samples
    )
    forecasts = list(forecast_it)
    tss = list(ts_it)

    return forecasts, tss ,predictor

# %%
def _get_lag_llama_predictions_tuned(dataset, prediction_length, num_samples=100):
    # Load the checkpoint with map_location set to 'cpu'
    ckpt = torch.load("lag-llama.ckpt", map_location=torch.device('cuda'),weights_only=True,)
    estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

    # Initialize the estimator with the required arguments
    estimator = LagLlamaEstimator(
        ckpt_path="lag-llama.ckpt",
        prediction_length=prediction_length,
        context_length=32,

        # scaling="mean",
        nonnegative_pred_samples=True,
        aug_prob=0,
        lr=0.0005,
        
        # estimator args
        input_size=estimator_args["input_size"],
        n_layer=estimator_args["n_layer"],
        n_embd_per_head=estimator_args["n_embd_per_head"],
        n_head=estimator_args["n_head"],
        scaling=estimator_args["scaling"],
        time_feat=estimator_args["time_feat"],

         # linear positional encoding scaling
        # rope_scaling={
        #     "type": "linear",
        #     "factor": max(1.0, (32 + prediction_length) / estimator_args["context_length"]),
        # },
        
        batch_size=32,
        num_parallel_samples=num_samples,
        trainer_kwargs = {"max_epochs": 200,}, # <- lightning trainer arguments
    )
    
    predictor = estimator.train(dataset, cache_data=True, shuffle_buffer_length=1000,verbose=False)

    # Generate forecasts and time series predictions
    forecast_it, ts_it = make_evaluation_predictions(
        dataset=dataset, predictor=predictor, num_samples=num_samples
    )
    forecasts = list(forecast_it)
    tss = list(ts_it)

    return forecasts, tss ,predictor

# %%
df = pd.read_csv('input/test_data.csv')
col=['ALL_DATE','Region','SKU','QTY']
df.columns=col
df["ALL_DATE"]=pd.to_datetime(df["ALL_DATE"],format="%d-%m-%Y")

# Create a complete date range for the dataset
start_date = df['ALL_DATE'].min()
end_date = df['ALL_DATE'].max()
date_range = pd.date_range(start=start_date, end=end_date, freq='MS')

# Create a DataFrame with all dates
all_dates_df = pd.DataFrame({'ALL_DATE': date_range})

# Merge the complete date range with the original data
df = all_dates_df.merge(df, on='ALL_DATE', how='left')
df.fillna(0, inplace=True)

df.set_index("ALL_DATE", inplace=True)

# %%
df.head()
# Out:
#            Region SKU     QTY
# ALL_DATE
# 2021-01-01      A   B  12.328
# 2021-02-01      A   B  20.145
# 2021-03-01      A   B  15.944
# 2021-04-01      A   B   3.442
# 2021-05-01      A   B  20.568

# %%
df=df[['QTY']]

# %%
df.shape
# Out:
# (59, 1)

# %%
def _get_lag_llama_dataset(dataset):
    # avoid mutations
    dataset = dataset.copy()

    # convert numerical columns to `float32`
    for col in dataset.columns:
        if dataset[col].dtype != "object" and not pd.api.types.is_string_dtype(
            dataset[col]
        ):
            dataset[col] = dataset[col].astype("float32")
    # create a `PandasDataset`
    backtest_dataset = PandasDataset(dict(dataset))
    return backtest_dataset

# %%
test_length=8
train_length = df.shape[0]-test_length

train_df=df[:train_length]
train_dataset = _get_lag_llama_dataset(dataset=train_df)
prediction_length =test_length # prediction length
train_samples = train_df.shape[0] # sampled from the distribution for each timestep

test_df=df[train_length:]
test_dataset = _get_lag_llama_dataset(dataset=test_df)
test_samples = train_df.shape[0] # sampled from the distribution for each timestep

# %%
forecasts, tss,predictor = _get_lag_llama_predictions(
    train_dataset, prediction_length, train_samples
)

# %%
def generate_forecasts(predictor, test_dataset):
    # Generate forecasts
    forecast_it, ts_it = make_evaluation_predictions(
        dataset=test_dataset, predictor=predictor, num_samples=len(test_dataset)  # Increased samples for better estimates
    )
    test_forecasts = list(forecast_it)
    test_tss = list(ts_it)

    return test_forecasts, test_tss

# %%
plt.figure(figsize=(15, 7))
date_formatter = mdates.DateFormatter("%d-%m-%Y")
plt.rcParams.update({"font.size": 12})

ts = tss[0]
forecast = forecasts[0]
fitted_values = ts[:train_length]

plt.plot(ts.to_timestamp(), label="Actual", color='blue')
plt.plot(fitted_values.to_timestamp(), label="Fitted", color='red',linestyle='--')
forecast.plot(color="green")
plt.xlabel("Date")
plt.ylabel("Quantity")
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_formatter(date_formatter)
plt.legend()
plt.title("Forecast vs Actual vs Fitted Series")

plt.show()

forecasted_values = forecast.samples.mean(axis=0)
print("Forecasted Values:", forecasted_values)
#print("Fitted Values:", fitted_values.values)
# Out:
# Forecasted Values: [5.413523  6.6811075 5.7141247 6.4579    5.904498  6.531212  7.3240848
#  6.9979086]

# %%
evaluator = Evaluator()
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))

mae = round(agg_metrics['abs_error'],2)
mape = round(agg_metrics['MAPE']*100,2)
rmse = round(agg_metrics['RMSE'],2)
print("Lag LLama MAE: ",mae)
print("Lag LLama MAPE: ",mape)
print("Lag LLama RMSE: ",rmse)
# Out:
# Running evaluation: 1it [00:00, 167.52it/s]
# Lag LLama MAE:  33.25
# Lag LLama MAPE:  58.26
# Lag LLama RMSE:  5.14

# %%
test_df=df[train_length:]
test_dataset = _get_lag_llama_dataset(dataset=test_df)

# Generate forecasts
test_forecasts, test_tss = generate_forecasts(predictor, test_dataset)

# %%
test_tss_list = [round(item,2) for sublist in test_tss[0].values.tolist() for item in sublist]

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
mae = mean_absolute_error(test_tss_list, forecasted_values)
mape = mean_absolute_percentage_error(test_tss_list, forecasted_values)
rmse = np.sqrt(mean_squared_error(test_tss_list, forecasted_values))

print("Test Evaluation Metrics:")
print("MAE:", round(mae, 2))
print("MAPE:", round(mape * 100, 2))
print("RMSE:", round(rmse, 2))
# Out:
# Test Evaluation Metrics:
# MAE: 2.52
# MAPE: 91.24
# RMSE: 3.03

# %%
forecasts_tuned, tss_tuned,predictor_tuned = _get_lag_llama_predictions_tuned(
    train_dataset, prediction_length, train_samples
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3050') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# Training: |                                                                                      | 0/? [00:00<…
# Epoch 0, global step 50: 'train_loss' reached 2.76378 (best 2.76378), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 1.36196 (best 1.36196), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 1.02983 (best 1.02983), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.46550 (best 0.46550), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.41950 (best 0.41950), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' was not in top 1
# Epoch 6, global step 350: 'train_loss' reached 0.23696 (best 0.23696), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 0.12493 (best 0.12493), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' was not in top 1
# Epoch 9, global step 500: 'train_loss' reached 0.05519 (best 0.05519), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached -0.15506 (best -0.15506), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' was not in top 1
# Epoch 12, global step 650: 'train_loss' reached -0.24759 (best -0.24759), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' was not in top 1
# Epoch 14, global step 750: 'train_loss' was not in top 1
# Epoch 15, global step 800: 'train_loss' was not in top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' reached -0.37578 (best -0.37578), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' was not in top 1
# Epoch 19, global step 1000: 'train_loss' reached -0.46681 (best -0.46681), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' was not in top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' reached -0.49057 (best -0.49057), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=22-step=1150.ckpt' as top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' was not in top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' reached -0.54632 (best -0.54632), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=26-step=1350.ckpt' as top 1
# Epoch 27, global step 1400: 'train_loss' reached -0.64892 (best -0.64892), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=27-step=1400.ckpt' as top 1
# Epoch 28, global step 1450: 'train_loss' reached -0.65766 (best -0.65766), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' reached -0.68663 (best -0.68663), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=29-step=1500.ckpt' as top 1
# Epoch 30, global step 1550: 'train_loss' reached -0.82519 (best -0.82519), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=30-step=1550.ckpt' as top 1
# Epoch 31, global step 1600: 'train_loss' was not in top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' was not in top 1
# Epoch 35, global step 1800: 'train_loss' was not in top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' was not in top 1
# Epoch 39, global step 2000: 'train_loss' was not in top 1
# Epoch 40, global step 2050: 'train_loss' reached -0.93633 (best -0.93633), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=40-step=2050.ckpt' as top 1
# Epoch 41, global step 2100: 'train_loss' reached -0.99407 (best -0.99407), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=41-step=2100.ckpt' as top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' reached -1.15413 (best -1.15413), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=44-step=2250.ckpt' as top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' was not in top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' was not in top 1
# Epoch 50, global step 2550: 'train_loss' reached -1.19013 (best -1.19013), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=50-step=2550.ckpt' as top 1
# Epoch 51, global step 2600: 'train_loss' was not in top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' was not in top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' was not in top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' reached -1.22086 (best -1.22086), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=60-step=3050.ckpt' as top 1
# Epoch 61, global step 3100: 'train_loss' was not in top 1
# Epoch 62, global step 3150: 'train_loss' was not in top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' reached -1.40183 (best -1.40183), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=64-step=3250.ckpt' as top 1
# Epoch 65, global step 3300: 'train_loss' was not in top 1
# Epoch 66, global step 3350: 'train_loss' was not in top 1
# Epoch 67, global step 3400: 'train_loss' was not in top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' was not in top 1
# Epoch 70, global step 3550: 'train_loss' reached -1.41257 (best -1.41257), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=70-step=3550.ckpt' as top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' was not in top 1
# Epoch 73, global step 3700: 'train_loss' was not in top 1
# Epoch 74, global step 3750: 'train_loss' was not in top 1
# Epoch 75, global step 3800: 'train_loss' was not in top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' was not in top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' was not in top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' reached -1.50027 (best -1.50027), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=83-step=4200.ckpt' as top 1
# Epoch 84, global step 4250: 'train_loss' was not in top 1
# Epoch 85, global step 4300: 'train_loss' reached -1.57611 (best -1.57611), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=85-step=4300.ckpt' as top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' was not in top 1
# Epoch 89, global step 4500: 'train_loss' was not in top 1
# Epoch 90, global step 4550: 'train_loss' reached -1.62275 (best -1.62275), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=90-step=4550.ckpt' as top 1
# Epoch 91, global step 4600: 'train_loss' was not in top 1
# Epoch 92, global step 4650: 'train_loss' was not in top 1
# Epoch 93, global step 4700: 'train_loss' was not in top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' was not in top 1
# Epoch 96, global step 4850: 'train_loss' was not in top 1
# Epoch 97, global step 4900: 'train_loss' was not in top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# Epoch 100, global step 5050: 'train_loss' was not in top 1
# Epoch 101, global step 5100: 'train_loss' reached -1.64131 (best -1.64131), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=101-step=5100.ckpt' as top 1
# Epoch 102, global step 5150: 'train_loss' reached -1.67848 (best -1.67848), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=102-step=5150.ckpt' as top 1
# Epoch 103, global step 5200: 'train_loss' was not in top 1
# Epoch 104, global step 5250: 'train_loss' was not in top 1
# Epoch 105, global step 5300: 'train_loss' was not in top 1
# Epoch 106, global step 5350: 'train_loss' was not in top 1
# Epoch 107, global step 5400: 'train_loss' was not in top 1
# Epoch 108, global step 5450: 'train_loss' was not in top 1
# Epoch 109, global step 5500: 'train_loss' was not in top 1
# Epoch 110, global step 5550: 'train_loss' reached -1.76186 (best -1.76186), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=110-step=5550.ckpt' as top 1
# Epoch 111, global step 5600: 'train_loss' was not in top 1
# Epoch 112, global step 5650: 'train_loss' was not in top 1
# Epoch 113, global step 5700: 'train_loss' was not in top 1
# Epoch 114, global step 5750: 'train_loss' reached -1.79200 (best -1.79200), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=114-step=5750.ckpt' as top 1
# Epoch 115, global step 5800: 'train_loss' was not in top 1
# Epoch 116, global step 5850: 'train_loss' was not in top 1
# Epoch 117, global step 5900: 'train_loss' was not in top 1
# Epoch 118, global step 5950: 'train_loss' was not in top 1
# Epoch 119, global step 6000: 'train_loss' was not in top 1
# Epoch 120, global step 6050: 'train_loss' was not in top 1
# Epoch 121, global step 6100: 'train_loss' reached -1.82176 (best -1.82176), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=121-step=6100.ckpt' as top 1
# Epoch 122, global step 6150: 'train_loss' was not in top 1
# Epoch 123, global step 6200: 'train_loss' was not in top 1
# Epoch 124, global step 6250: 'train_loss' was not in top 1
# Epoch 125, global step 6300: 'train_loss' was not in top 1
# Epoch 126, global step 6350: 'train_loss' was not in top 1
# Epoch 127, global step 6400: 'train_loss' was not in top 1
# Epoch 128, global step 6450: 'train_loss' was not in top 1
# Epoch 129, global step 6500: 'train_loss' was not in top 1
# Epoch 130, global step 6550: 'train_loss' was not in top 1
# Epoch 131, global step 6600: 'train_loss' was not in top 1
# Epoch 132, global step 6650: 'train_loss' was not in top 1
# Epoch 133, global step 6700: 'train_loss' was not in top 1
# Epoch 134, global step 6750: 'train_loss' was not in top 1
# Epoch 135, global step 6800: 'train_loss' was not in top 1
# Epoch 136, global step 6850: 'train_loss' was not in top 1
# Epoch 137, global step 6900: 'train_loss' was not in top 1
# Epoch 138, global step 6950: 'train_loss' was not in top 1
# Epoch 139, global step 7000: 'train_loss' was not in top 1
# Epoch 140, global step 7050: 'train_loss' was not in top 1
# Epoch 141, global step 7100: 'train_loss' was not in top 1
# Epoch 142, global step 7150: 'train_loss' was not in top 1
# Epoch 143, global step 7200: 'train_loss' was not in top 1
# Epoch 144, global step 7250: 'train_loss' reached -1.82970 (best -1.82970), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=144-step=7250.ckpt' as top 1
# Epoch 145, global step 7300: 'train_loss' was not in top 1
# Epoch 146, global step 7350: 'train_loss' was not in top 1
# Epoch 147, global step 7400: 'train_loss' was not in top 1
# Epoch 148, global step 7450: 'train_loss' was not in top 1
# Epoch 149, global step 7500: 'train_loss' was not in top 1
# Epoch 150, global step 7550: 'train_loss' was not in top 1
# Epoch 151, global step 7600: 'train_loss' was not in top 1
# Epoch 152, global step 7650: 'train_loss' reached -1.87795 (best -1.87795), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=152-step=7650.ckpt' as top 1
# Epoch 153, global step 7700: 'train_loss' was not in top 1
# Epoch 154, global step 7750: 'train_loss' was not in top 1
# Epoch 155, global step 7800: 'train_loss' was not in top 1
# Epoch 156, global step 7850: 'train_loss' was not in top 1
# Epoch 157, global step 7900: 'train_loss' was not in top 1
# Epoch 158, global step 7950: 'train_loss' was not in top 1
# Epoch 159, global step 8000: 'train_loss' was not in top 1
# Epoch 160, global step 8050: 'train_loss' was not in top 1
# Epoch 161, global step 8100: 'train_loss' was not in top 1
# Epoch 162, global step 8150: 'train_loss' was not in top 1
# Epoch 163, global step 8200: 'train_loss' was not in top 1
# Epoch 164, global step 8250: 'train_loss' was not in top 1
# Epoch 165, global step 8300: 'train_loss' was not in top 1
# Epoch 166, global step 8350: 'train_loss' was not in top 1
# Epoch 167, global step 8400: 'train_loss' was not in top 1
# Epoch 168, global step 8450: 'train_loss' was not in top 1
# Epoch 169, global step 8500: 'train_loss' was not in top 1
# Epoch 170, global step 8550: 'train_loss' was not in top 1
# Epoch 171, global step 8600: 'train_loss' reached -1.91675 (best -1.91675), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=171-step=8600.ckpt' as top 1
# Epoch 172, global step 8650: 'train_loss' was not in top 1
# Epoch 173, global step 8700: 'train_loss' was not in top 1
# Epoch 174, global step 8750: 'train_loss' was not in top 1
# Epoch 175, global step 8800: 'train_loss' reached -1.94863 (best -1.94863), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=175-step=8800.ckpt' as top 1
# Epoch 176, global step 8850: 'train_loss' was not in top 1
# Epoch 177, global step 8900: 'train_loss' was not in top 1
# Epoch 178, global step 8950: 'train_loss' was not in top 1
# Epoch 179, global step 9000: 'train_loss' was not in top 1
# Epoch 180, global step 9050: 'train_loss' was not in top 1
# Epoch 181, global step 9100: 'train_loss' was not in top 1
# Epoch 182, global step 9150: 'train_loss' was not in top 1
# Epoch 183, global step 9200: 'train_loss' was not in top 1
# Epoch 184, global step 9250: 'train_loss' was not in top 1
# Epoch 185, global step 9300: 'train_loss' was not in top 1
# Epoch 186, global step 9350: 'train_loss' was not in top 1
# Epoch 187, global step 9400: 'train_loss' reached -1.98550 (best -1.98550), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=187-step=9400.ckpt' as top 1
# Epoch 188, global step 9450: 'train_loss' was not in top 1
# Epoch 189, global step 9500: 'train_loss' reached -2.03472 (best -2.03472), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=189-step=9500.ckpt' as top 1
# Epoch 190, global step 9550: 'train_loss' was not in top 1
# Epoch 191, global step 9600: 'train_loss' was not in top 1
# Epoch 192, global step 9650: 'train_loss' reached -2.08254 (best -2.08254), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_6\\checkpoints\\epoch=192-step=9650.ckpt' as top 1
# Epoch 193, global step 9700: 'train_loss' was not in top 1
# Epoch 194, global step 9750: 'train_loss' was not in top 1
# Epoch 195, global step 9800: 'train_loss' was not in top 1
# Epoch 196, global step 9850: 'train_loss' was not in top 1
# Epoch 197, global step 9900: 'train_loss' was not in top 1
# Epoch 198, global step 9950: 'train_loss' was not in top 1
# Epoch 199, global step 10000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=200` reached.

# %%
evaluator = Evaluator()
agg_metrics_tuned, ts_metrics_tuned = evaluator(iter(tss_tuned), iter(forecasts_tuned))

tmae = round(agg_metrics_tuned['abs_error'],2)
tmape = round(agg_metrics_tuned['MAPE']*100,2)
trmse = round(agg_metrics_tuned['RMSE'],2)
print("Fine Tuned Lag LLama MAE: ",tmae)
print("Fine Tuned LLama MAPE: ",tmape)
print("Fine Tuned LLama RMSE: ",trmse)
# Out:
# Running evaluation: 1it [00:00, 105.91it/s]
# Fine Tuned Lag LLama MAE:  0.78
# Fine Tuned LLama MAPE:  1.89
# Fine Tuned LLama RMSE:  0.14

# %%
plt.figure(figsize=(15, 7))
date_formatter = mdates.DateFormatter("%d-%m-%Y")
plt.rcParams.update({"font.size": 12})

ts_tuned = tss_tuned[0]
forecast_tuned = forecasts_tuned[0]
fitted_values_tuned = ts_tuned[:train_length]

plt.plot(ts_tuned.to_timestamp(), label="Actual", color='blue')
plt.plot(fitted_values_tuned.to_timestamp(), label="Fitted", color='red',linestyle='--')
forecast_tuned.plot(color="green")
plt.xlabel("Date")
plt.ylabel("Quantity")
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_formatter(date_formatter)
plt.legend()
plt.title("Forecast vs Actual vs Fitted Series")

plt.show()

forecast_tuned_values = forecast_tuned.samples.mean(axis=0)
print("Tuned Forecasted Values:", forecast_tuned_values)
# Out:
# Tuned Forecasted Values: [10.3617935  6.1622834 16.693123  12.2708645  7.144559   4.9558473
#   6.95429    2.07517  ]

# %%
test_df=df[train_length:]
test_dataset = _get_lag_llama_dataset(dataset=test_df)

# Generate forecasts
test_forecasts, test_tss = generate_forecasts(predictor_tuned, test_dataset)

# %%
test_tss_list = [round(item,2) for sublist in test_tss[0].values.tolist() for item in sublist]

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
mae = mean_absolute_error(test_tss_list, forecast_tuned_values)
mape = mean_absolute_percentage_error(test_tss_list, forecast_tuned_values)
rmse = np.sqrt(mean_squared_error(test_tss_list, forecast_tuned_values))

print("Tuned Test Evaluation Metrics:")
print("MAE:", round(mae, 2))
print("MAPE:", round(mape * 100, 2))
print("RMSE:", round(rmse, 2))
# Out:
# Tuned Test Evaluation Metrics:
# MAE: 4.6
# MAPE: 129.27
# RMSE: 6.22

# %%
from gluonts.torch import TemporalFusionTransformerEstimator, DeepAREstimator 

tft_estimator = TemporalFusionTransformerEstimator(
  prediction_length=prediction_length, 
  context_length=32, 
  freq="MS", 
  trainer_kwargs={"max_epochs": 5}) 

deepar_estimator = DeepAREstimator(
  prediction_length=prediction_length, 
  context_length=32, 
  freq="MS", 
  trainer_kwargs={"max_epochs": 5})

# %%
tft_predictor = tft_estimator.train(train_dataset) 
deepar_predictor = deepar_estimator.train(train_dataset)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                           | Params | In sizes                                                                           | Out sizes
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TemporalFusionTransformerModel | 87.4 K | [[1, 32], [1, 32], [1, 1], [1, 1], [1, 40, 1], [1, 40, 0], [1, 32, 0], [1, 32, 0]] | [1, 9, 8]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# 87.4 K    Trainable params
# 0         Non-trainable params
# 87.4 K    Total params
# 0.350     Total estimated model params size (MB)
# Training: |                                                                                      | 0/? [00:00<…
# Epoch 0, global step 50: 'train_loss' reached 30.23370 (best 30.23370), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_7\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 27.30127 (best 27.30127), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_7\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 24.18978 (best 24.18978), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_7\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 21.63833 (best 21.63833), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_7\\checkpoints\\epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 18.35924 (best 18.35924), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_7\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=5` reached.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type        | Params | In sizes                                                  | Out sizes
# ----------------------------------------------------------------------------------------------------------------
# 0 | model | DeepARModel | 23.3 K | [[1, 1], [1, 1], [1, 68, 2], [1, 68], [1, 68], [1, 8, 2]] | [1, 100, 8]
# ----------------------------------------------------------------------------------------------------------------
# 23.3 K    Trainable params
# 0         Non-trainable params
# 23.3 K    Total params
# 0.093     Total estimated model params size (MB)
# Training: |                                                                                      | 0/? [00:00<…
# Epoch 0, global step 50: 'train_loss' reached 2.30729 (best 2.30729), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_8\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 2.00375 (best 2.00375), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_8\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 1.76937 (best 1.76937), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_8\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 1.57344 (best 1.57344), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_8\\checkpoints\\epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 1.39029 (best 1.39029), saving model to 'D:\\Workspaces\\MLWorkspace\\LagLlama-Models\\lightning_logs\\version_8\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=5` reached.

# %%
# Make predictions

tft_forecast_it, tft_ts_it = make_evaluation_predictions(
  dataset=train_dataset, 
  predictor=tft_predictor) 

deepar_forecast_it, deepar_ts_it = make_evaluation_predictions(
  dataset=train_dataset, 
  predictor=deepar_predictor) 

tft_forecasts = list(tft_forecast_it) 
tft_tss = list(tft_ts_it) 

deepar_forecasts = list(deepar_forecast_it) 
deepar_tss = list(deepar_ts_it) 

# Get evaluation metrics
tft_agg_metrics, tft_ts_metrics = evaluator(iter(tft_tss), iter(tft_forecasts)) 
deepar_agg_metrics, deepar_ts_metrics = evaluator(iter(deepar_tss), iter(deepar_forecasts))
# Out:
# Running evaluation: 0it [00:00, ?it/s]The mean prediction is not stored in the forecast data; the median is being returned instead. This behaviour may change in the future.
# The mean prediction is not stored in the forecast data; the median is being returned instead. This behaviour may change in the future.
# Running evaluation: 1it [00:00, 217.39it/s]
# Running evaluation: 1it [00:00, 191.20it/s]

# %%
from prettytable import PrettyTable ,TableStyle
# Model metrics
table = PrettyTable()

# Define column names
table.field_names = ["Model", "MAE", "MAPE (%)", "RMSE"]
table.set_style(TableStyle.DOUBLE_BORDER)
# Define row values
table.add_rows([
    ["Lag LLama", round(agg_metrics['abs_error'], 2), round(agg_metrics['MAPE'] * 100, 2), round(agg_metrics['RMSE'], 2)],
    ["Fine Tune Lag LLama", round(agg_metrics_tuned['abs_error'], 2), round(agg_metrics_tuned['MAPE'] * 100, 2), round(agg_metrics_tuned['RMSE'], 2)],
    ["TFT", round(tft_agg_metrics['abs_error'], 2), round(tft_agg_metrics['MAPE'] * 100, 2), round(tft_agg_metrics['RMSE'], 2)],
    ["DEEP-AR", round(deepar_agg_metrics['abs_error'], 2), round(deepar_agg_metrics['MAPE'] * 100, 2), round(deepar_agg_metrics['RMSE'], 2)]
])

# Set table style
table.align = "c"
table.border = True
table.header = True
table.junction_char = "+"

# Print table
print(table)
# Out:
# ╔═════════════════════╦═══════╦══════════╦══════╗
# ║        Model        ║  MAE  ║ MAPE (%) ║ RMSE ║
# ╠═════════════════════+═══════+══════════+══════╣
# ║      Lag LLama      ║ 33.25 ║  58.26   ║ 5.14 ║
# ║ Fine Tune Lag LLama ║  0.78 ║   1.89   ║ 0.14 ║
# ║         TFT         ║  25.9 ║  46.77   ║ 4.0  ║
# ║       DEEP-AR       ║  29.6 ║  66.65   ║ 4.4  ║
# ╚═════════════════════╩═══════╩══════════╩══════╝
